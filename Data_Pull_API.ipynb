# %% [markdown]
# <a href="https://colab.research.google.com/github/soumo99/Google_Colab_codes/blob/main/Data_Pull_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Code for Data Pulling from an API

# %%
import requests
import pandas as pd

# API endpoint URL
url = 'http://universities.hipolabs.com/search?country=United+States'


response = requests.get(url)


if response.status_code == 200:
    #prints the data in a json file
    data = response.json()

    #converts the json file to the dataframe
    df = pd.DataFrame(data)

    print(df)

else:

    print('Failed to fetch data from the API')
# Out:
#             country           domains alpha_two_code state-province  \
# 0     United States    [marywood.edu]             US           None
# 1     United States  [lindenwood.edu]             US           None
# 2     United States    [sullivan.edu]             US           None
# 3     United States        [fscj.edu]             US           None
# 4     United States      [xavier.edu]             US           None
# ...             ...               ...            ...            ...
# 4530  United States         [csu.edu]             US           None
# 4531  United States   [csupueblo.edu]             US           None
# 4532  United States         [bau.edu]             US           None
# 4533  United States       [siena.edu]             US           None
# 4534  United States       [txwes.edu]             US           None
#
#                          web_pages                                   name
# 0        [http://www.marywood.edu]                    Marywood University
# ...

# %%
data
# Out:
# [{'country': 'United States',
#   'domains': ['marywood.edu'],
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'web_pages': ['http://www.marywood.edu'],
#   'name': 'Marywood University'},
#  {'country': 'United States',
#   'domains': ['lindenwood.edu'],
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'web_pages': ['http://www.lindenwood.edu/'],
#   'name': 'Lindenwood University'},
#  {'country': 'United States',
#   'domains': ['sullivan.edu'],
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'web_pages': ['https://sullivan.edu/'],
#   'name': 'Sullivan University'},
#  {'country': 'United States',
#   'domains': ['fscj.edu'],
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'web_pages': ['https://www.fscj.edu/'],
#   'name': 'Florida State College at Jacksonville'},
#  {'country': 'United States',
#   'domains': ['xavier.edu'],
#   'alpha_two_code': 'US',
#   'state-province': None,
#   'web_pages': ['https://www.xavier.edu/'],
# ...

# %%
df
# Out:
#             country           domains alpha_two_code state-province  \
# 0     United States    [marywood.edu]             US           None
# 1     United States  [lindenwood.edu]             US           None
# 2     United States    [sullivan.edu]             US           None
# 3     United States        [fscj.edu]             US           None
# 4     United States      [xavier.edu]             US           None
# ...             ...               ...            ...            ...
# 4530  United States         [csu.edu]             US           None
# 4531  United States   [csupueblo.edu]             US           None
# 4532  United States         [bau.edu]             US           None
# 4533  United States       [siena.edu]             US           None
# 4534  United States       [txwes.edu]             US           None
#
#                          web_pages                                   name
# 0        [http://www.marywood.edu]                    Marywood University
# ...

# %%
json = df.to_json()

# %%
print(json)
# Out:
# {"country":{"0":"United States","1":"United States","2":"United States","3":"United States","4":"United States","5":"United States","6":"United States","7":"United States","8":"United States","9":"United States","10":"United States","11":"United States","12":"United States","13":"United States","14":"United States","15":"United States","16":"United States","17":"United States","18":"United States","19":"United States","20":"United States","21":"United States","22":"United States","23":"United States","24":"United States","25":"United States","26":"United States","27":"United States","28":"United States","29":"United States","30":"United States","31":"United States","32":"United States","33":"United States","34":"United States","35":"United States","36":"United States","37":"United States","38":"United States","39":"United States","40":"United States","41":"United States","42":"United States","43":"United States","44":"United States","45":"United States","46":"United States","47":"Uni
# ...

# %%
pip install flask

# %% [markdown]
# Converting Dataframe to an API

# %%
from flask import Flask, jsonify
import json

app = Flask(__name__)

# Load JSON data from a file
with open('df.json') as json_file:
    json_data = json.load(json_file)

# Define an API route
@app.route('/api/data', methods=['GET'])
def get_data():
    return jsonify(json_data)

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5000)
